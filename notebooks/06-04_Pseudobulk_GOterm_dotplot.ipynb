# %%
suppressPackageStartupMessages({
  library(AnnotationDbi)
  library(org.Hs.eg.db)
  library(clusterProfiler)
  library(enrichplot)
  library(ggplot2)
  library(tools)
  library(here)
})

# %%
setwd('..')

# %%
getwd()
# Out:
# [1] "C:/Users/yyyyx/Work/OC43_machine_learning/Regression_Modeling_of_OC43_Coronavirus_Viral_Burden_from_Host_Single-cell_Transcriptomes_Using_Explainable_Machine_Learning"

# %%
utils <- new.env()

# 2. 그 공간 안에 스크립트 내용을 실행합니다.
sys.source(here::here("scripts", "utils.r"), envir = utils)

# %%
utils$run_go_enrichment("./Pseudobulk/Sig_deg/Sig_DEG_High infection_vs_No infection_LFC0.58.csv",plot_title = "High-infection vs No-infection", out_dir_csv = "./Pseudobulk/GO_results/",
                              out_dir_fig = "./Pseudobulk/GO_plots/")
# Out:
# [*] Processing: Sig_DEG_High infection_vs_No infection_LFC0.58
#
# Warning message in clusterProfiler::bitr(symbols, fromType = "SYMBOL", toType = "ENTREZID", :
# "5.54% of input gene IDs are fail to map..."
# Mapped 921 genes to Entrez IDs.
#
# [+] Results saved to: ./Pesudobulk/GO_results/

# %%
utils$run_go_enrichment("./Pseudobulk/Sig_deg/Sig_DEG_Low infection_vs_No infection_LFC0.58.csv",plot_title = "Low-infection vs No-infection", out_dir_csv = "./Pseudobulk/GO_results/",
                              out_dir_fig = "./Pseudobulk/GO_plots/")
# Out:
# [*] Processing: Sig_DEG_Low infection_vs_No infection_LFC0.58
#
# Warning message in clusterProfiler::bitr(symbols, fromType = "SYMBOL", toType = "ENTREZID", :
# "4.97% of input gene IDs are fail to map..."
# Mapped 727 genes to Entrez IDs.
#
# [+] Results saved to: ./Pesudobulk/GO_results/

# %%
utils$run_go_enrichment("./Pseudobulk/Sig_deg/Sig_DEG_High infection_vs_Low infection_LFC0.58.csv",plot_title = "High-infection vs Low-infection", out_dir_csv = "./Pseudobulk/GO_results/",
                              out_dir_fig = "./Pseudobulk/GO_plots/")
# Out:
# [*] Processing: Sig_DEG_High infection_vs_Low infection_LFC0.58
#
# Warning message in clusterProfiler::bitr(symbols, fromType = "SYMBOL", toType = "ENTREZID", :
# "3.88% of input gene IDs are fail to map..."
# Mapped 421 genes to Entrez IDs.
#
# [+] Results saved to: ./Pesudobulk/GO_results/

# %%
sessionInfo()
# Out:
# R version 4.2.3 (2023-03-15 ucrt)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 26200)
#
# Matrix products: default
#
# locale:
# [1] LC_COLLATE=Korean_Korea.utf8  LC_CTYPE=Korean_Korea.utf8
# [3] LC_MONETARY=Korean_Korea.utf8 LC_NUMERIC=C
# [5] LC_TIME=Korean_Korea.utf8
#
# attached base packages:
# [1] tools     stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] here_1.0.2            ggplot2_3.5.1         enrichplot_1.18.4
#  [4] clusterProfiler_4.6.2 org.Hs.eg.db_3.16.0   AnnotationDbi_1.60.2
#  [7] IRanges_2.32.0        S4Vectors_0.36.2      Biobase_2.58.0
# [10] BiocGenerics_0.44.0
#
# loaded via a namespace (and not attached):
#   [1] fgsea_1.24.0           colorspace_2.1-0       ggtree_3.6.2
#   [4] gson_0.1.0             rprojroot_2.1.1        IRdisplay_1.1
#   [7] qvalue_2.30.0          XVector_0.38.0         base64enc_0.1-3
# ...
